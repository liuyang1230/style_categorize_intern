# %% [markdown]
# <a href="https://colab.research.google.com/github/liuyang1230/style_categorize_intern/blob/main/04_1_%E3%82%B9%E3%82%BF%E3%82%A4%E3%83%AB%E5%88%86%E9%A1%9E_data_aug_VGG16_size_cut_Adam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import math
# AnoGANに必要なモジュールを読込む
#from __future__ import print_function
from keras import backend as K
from keras import initializers
from keras.backend.tensorflow_backend import set_session
from keras.datasets import mnist
from keras.layers import Input, Reshape, Dense, Dropout, MaxPooling2D, Conv2D, Flatten
from keras.layers import Conv2DTranspose, LeakyReLU
from keras.layers.core import Activation
from keras.layers.normalization import BatchNormalization
from keras.models import Sequential, Model
from keras.optimizers import Adam, RMSprop
from keras.utils.generic_utils import Progbar
from keras.preprocessing.image import load_img, img_to_array,array_to_img
import keras.utils
from keras import utils as np_utils
from keras.utils import to_categorical

import tensorflow as tf
from tqdm import tqdm
import matplotlib.pyplot as plt
import cv2
import os
import argparse
# %matplotlib inline 
import glob
from PIL import Image
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
config = tf.ConfigProto(gpu_options=tf.GPUOptions(visible_device_list="7",allow_growth=True))
set_session(tf.Session(config=config))

# %%
target_size_1=(420,280) #load
target_size_2 = (350,140) #test
#target_size_3 =(420,168)

# %%
def size_cut(image):
    _,h,w,_ = image.shape
    center_h = h/2 
    center_w = w/2
    
    top = int(center_h  - h/2)
    bottom = int(center_h  + h/2)
    left = int(center_w - 3*w/10)
    right = int(center_w + 3*w/10)
    
    image = image[:,top:bottom, left:right, :]

    return image

# %%
def random_crop(image,crop_size):
    _,h,w,_ = image.shape
    #np.random.seed(100)
    top = np.random.randint(0, h-crop_size[0])
    left = np.random.randint(0, w-crop_size[1])
    
    bottom = top + crop_size[0]
    right = left + crop_size[1]
    
    image = image[:,top:bottom, left:right, :]
    return image

# %%
#教師データとテストデータの分類
def data_classification(jpg_list,target_size_load): 

    IMG_test_dat = []
    IMG_train_dat = []
    #画像のサイス切り取り
    IMG_dat = []
    for num in range(len(jpg_list)):
        img= load_img(jpg_list[num],target_size = target_size_load, interpolation='bilinear')
        npimg = img_to_array(img)
        IMG_dat.append(npimg)
    IMG_dat = np.asarray(IMG_dat)
    img_loaded = size_cut(IMG_dat)
    
    for num in range(len(img_loaded)):
        #kerasでファイルを読み込み
        npimg = img_loaded[num]
        if(num < 70) :
            #画像(配列変換隅)のデータセット一覧
            IMG_train_dat.append(npimg)
        else :
            #画像(配列変換隅)のデータセット一覧
            IMG_test_dat.append(npimg)
    IMG_train_dat = np.asarray(IMG_train_dat)
    IMG_test_dat = np.asarray(IMG_test_dat)
    return IMG_train_dat, IMG_test_dat

# %%
def size_change_test (img, target_size_test ):
    IMG_dat = []
    for num in range(len(img)):
        npimg = img[num]
        npimg = cv2.resize(npimg,(target_size_test[1], target_size_test[0]))
        IMG_dat.append(npimg)
    IMG_dat = np.asarray(IMG_dat)
    IMG_dat =IMG_dat.astype(np.uint8)
    return IMG_dat

# %%
#Ethnic類
os.chdir("/notebooks/note/image/Ethnic")

jpg_list = sorted(glob.glob('*.jpg'))

IMG_ETHNIC_train_dat,IMG_ETHNIC_test_dat= data_classification(jpg_list, target_size_1)  
#テストデータ
IMG_ETHNIC_test_dat=size_change_test(IMG_ETHNIC_test_dat, target_size_2)
#教師データの水増し
IMG_ETHNIC_train1 = random_crop(IMG_ETHNIC_train_dat[:70,:,:,:],target_size_2)
IMG_ETHNIC_train2 = random_crop(IMG_ETHNIC_train_dat[:70,:,:,:],target_size_2)
IMG_ETHNIC_train3 = random_crop(IMG_ETHNIC_train_dat[:70,:,:,:],target_size_2)
IMG_ETHNIC_train4 = random_crop(IMG_ETHNIC_train_dat[:70,:,:,:],target_size_2)
IMG_ETHNIC_train5 = random_crop(IMG_ETHNIC_train_dat[:70,:,:,:],target_size_2)

IMG_ETHNIC_train = np.vstack([IMG_ETHNIC_train1,IMG_ETHNIC_train2,IMG_ETHNIC_train3,IMG_ETHNIC_train4,IMG_ETHNIC_train5])

ethnic_label = np.array([0]*380)

# %%
#Feminine類
os.chdir("/notebooks/note/image/Feminine")

jpg_list = sorted(glob.glob('*.jpg'))

IMG_FEMININE_train_dat,IMG_FEMININE_test_dat= data_classification(jpg_list, target_size_1)  
#テストデータ
IMG_FEMININE_test_dat=size_change_test(IMG_FEMININE_test_dat, target_size_2)
#教師データの水増し
IMG_FEMININE_train1 = random_crop(IMG_FEMININE_train_dat[:70,:,:,:],target_size_2)
IMG_FEMININE_train2 = random_crop(IMG_FEMININE_train_dat[:70,:,:,:],target_size_2)
IMG_FEMININE_train3 = random_crop(IMG_FEMININE_train_dat[:70,:,:,:],target_size_2)
IMG_FEMININE_train4 = random_crop(IMG_FEMININE_train_dat[:70,:,:,:],target_size_2)
IMG_FEMININE_train5 = random_crop(IMG_FEMININE_train_dat[:70,:,:,:],target_size_2)

IMG_FEMININE_train = np.vstack([IMG_FEMININE_train1,IMG_FEMININE_train2,IMG_FEMININE_train3,IMG_FEMININE_train4,IMG_FEMININE_train5])

feminine_label = np.array([1]*380)

# %%
#Masculine類
os.chdir("/notebooks/note/image/Masculine")

jpg_list = sorted(glob.glob('*.jpg'))

IMG_MASCULINE_train_dat,IMG_MASCULINE_test_dat= data_classification(jpg_list, target_size_1)  
#テストデータ
IMG_MASCULINE_test_dat=size_change_test(IMG_MASCULINE_test_dat, target_size_2)
#教師データの水増し
IMG_MASCULINE_train1 = random_crop(IMG_MASCULINE_train_dat[:70,:,:,:],target_size_2)
IMG_MASCULINE_train2 = random_crop(IMG_MASCULINE_train_dat[:70,:,:,:],target_size_2)
IMG_MASCULINE_train3 = random_crop(IMG_MASCULINE_train_dat[:70,:,:,:],target_size_2)
IMG_MASCULINE_train4 = random_crop(IMG_MASCULINE_train_dat[:70,:,:,:],target_size_2)
IMG_MASCULINE_train5 = random_crop(IMG_MASCULINE_train_dat[:70,:,:,:],target_size_2)

IMG_MASCULINE_train = np.vstack([IMG_MASCULINE_train1,IMG_MASCULINE_train2,IMG_MASCULINE_train3,IMG_MASCULINE_train4,IMG_MASCULINE_train5])

masculine_label = np.array([2]*380)

# %%
x_train=np.vstack([IMG_ETHNIC_train,IMG_FEMININE_train,IMG_MASCULINE_train])

# %%
y_train_ethnic = ethnic_label[:350]
y_train_feminine = feminine_label[:350]
y_train_masculine = masculine_label[:350]

# %%
y_test_ethnic = ethnic_label[350:]
y_test_feminine = feminine_label[350:]
y_test_masculine = masculine_label[350:]

# %%
x_test=np.vstack([IMG_ETHNIC_test_dat,IMG_FEMININE_test_dat,IMG_MASCULINE_test_dat])

# %%
y_train = np.concatenate([y_train_ethnic,y_train_feminine,y_train_masculine])
y_test = np.concatenate([y_test_ethnic,y_test_feminine,y_test_masculine])

# %%
num_classes = 3
epochs = 20
batch_size = 10
input_shape = (target_size_2[0],target_size_2[1],3)

# %%
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# ラベルはone-hot encodingを施す
y_train = y_train.astype('int32')
y_test = y_test.astype('int32')
y_train = keras.utils.np_utils.to_categorical(y_train, num_classes)
y_test =  keras.utils.np_utils.to_categorical(y_test, num_classes)

# %%
from keras.applications.vgg16 import VGG16, preprocess_input, decode_predictions

input_tensor = Input(shape=(target_size_2[0],target_size_2[1], 3))
vgg16_model = VGG16(include_top=False, weights='imagenet', input_tensor = input_tensor)

# %%
vgg16_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 350, 140, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 350, 140, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 350, 140, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 175, 70, 64)       0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 175, 70, 128)      73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 175, 70, 128)      147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 87, 35, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 87, 35, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 87, 35, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 87, 35, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 43, 17, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 43, 17, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 43, 17, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 43, 17, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 21, 8, 512)        0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 21, 8, 512)        2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 21, 8, 512)        2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 21, 8, 512)        2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 10, 4, 512)        0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
vgg16_out_shape = K.int_shape(vgg16_model.output)

# %%
top_model = Sequential()
#top_model.add(Conv2D(32, kernel_size=(3, 3),
#                 activation='relu',
#                 input_shape=(4,3,512)))
#top_model.add(Conv2D(64, (3, 3), activation='relu',strides = 2))
#top_model.add(Conv2D(128, (3, 3), activation='relu',strides = 2))
#top_model.add(Conv2D(256, (3, 3), activation='relu',strides = 2))
#top_model.add(MaxPooling2D(pool_size=(2, 2)))
#top_model.add(Dropout(0.25))
top_model.add(Flatten(input_shape=vgg16_model.output_shape[1:]))
top_model.add(Dense(2048, activation='relu'))
top_model.add(Dropout(0.5))
top_model.add(Dense(128, activation='relu'))

top_model.add(Dense(3, activation='softmax'))
#モデルの評価
top_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 20480)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2048)              41945088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               262272
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 42,207,747
# Trainable params: 42,207,747
# Non-trainable params: 0
# _________________________________________________________________

# %%
vgg16_model.input.shape
# Out:
# TensorShape([Dimension(None), Dimension(350), Dimension(140), Dimension(3)])

# %%
vgg16_model.output.shape
# Out:
# TensorShape([Dimension(None), Dimension(10), Dimension(4), Dimension(512)])

# %%
#top_model.add(Reshape(target_shape=(150, 100, 3),
#                      input_shape=list(top_model.output.get_shape().as_list()[1:])))
new_model = Model(inputs = vgg16_model.input, outputs = top_model(vgg16_model.output))
print('new model:', new_model)
new_model.summary()
# Out:
# new model: <keras.engine.training.Model object at 0x7facd396cd30>
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 350, 140, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 350, 140, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 350, 140, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 175, 70, 64)       0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 175, 70, 128)      73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 175, 70, 128)      147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 87, 35, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 87, 35, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 87, 35, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 87, 35, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 43, 17, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 43, 17, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 43, 17, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 43, 17, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 21, 8, 512)        0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 21, 8, 512)        2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 21, 8, 512)        2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 21, 8, 512)        2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 10, 4, 512)        0
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 3)                 42207747
# =================================================================
# Total params: 56,922,435
# Trainable params: 56,922,435
# Non-trainable params: 0
# _________________________________________________________________

# %%
new_model.layers[3].name
# Out:
# 'block1_pool'

# %%
for i in range(len(new_model.layers)):
    print(i, new_model.layers[i].name)
    
for layer in new_model.layers[:19]:
    layer.trainable = False
    
new_model.summary()
# Out:
# 0 input_1
# 1 block1_conv1
# 2 block1_conv2
# 3 block1_pool
# 4 block2_conv1
# 5 block2_conv2
# 6 block2_pool
# 7 block3_conv1
# 8 block3_conv2
# 9 block3_conv3
# 10 block3_pool
# 11 block4_conv1
# 12 block4_conv2
# 13 block4_conv3
# 14 block4_pool
# 15 block5_conv1
# 16 block5_conv2
# 17 block5_conv3
# 18 block5_pool
# 19 sequential_1
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 350, 140, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 350, 140, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 350, 140, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 175, 70, 64)       0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 175, 70, 128)      73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 175, 70, 128)      147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 87, 35, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 87, 35, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 87, 35, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 87, 35, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 43, 17, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 43, 17, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 43, 17, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 43, 17, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 21, 8, 512)        0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 21, 8, 512)        2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 21, 8, 512)        2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 21, 8, 512)        2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 10, 4, 512)        0
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 3)                 42207747
# =================================================================
# Total params: 56,922,435
# Trainable params: 42,207,747
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
new_model.compile(loss=keras.losses.categorical_crossentropy,
#                 optimizer=keras.optimizers.Adadelta(),
                  optimizer=keras.optimizers.Adam(lr=0.00001),
                  metrics=['accuracy'])
early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=5, verbose=0, mode='auto')
#モデルの学習
history = new_model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs,
          verbose=1, validation_data=(x_test, y_test),callbacks=[early_stopping])

#学習終了時の精度評価
score = new_model.evaluate(x_test, y_test, verbose=0)

print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Train on 1050 samples, validate on 90 samples
# Epoch 1/20
# 1050/1050 [==============================] - 11s 10ms/step - loss: 0.8609 - acc: 0.6067 - val_loss: 0.7436 - val_acc: 0.6667
# Epoch 2/20
# 1050/1050 [==============================] - 8s 8ms/step - loss: 0.3984 - acc: 0.8610 - val_loss: 0.5902 - val_acc: 0.7667
# Epoch 3/20
# 1050/1050 [==============================] - 8s 8ms/step - loss: 0.2118 - acc: 0.9400 - val_loss: 0.5504 - val_acc: 0.7556
# Epoch 4/20
# 1050/1050 [==============================] - 8s 8ms/step - loss: 0.1261 - acc: 0.9752 - val_loss: 0.5653 - val_acc: 0.7333
# Epoch 5/20
# 1050/1050 [==============================] - 8s 8ms/step - loss: 0.0807 - acc: 0.9829 - val_loss: 0.6023 - val_acc: 0.7222
# Epoch 6/20
# 1050/1050 [==============================] - 8s 8ms/step - loss: 0.0546 - acc: 0.9914 - val_loss: 0.6127 - val_acc: 0.7556
# Epoch 7/20
# 1050/1050 [==============================] - 8s 8ms/step - loss: 0.0384 - acc: 0.9990 - val_loss: 0.6159 - val_acc: 0.7333
# Epoch 8/20
# 1050/1050 [==============================] - 8s 8ms/step - loss: 0.0307 - acc: 0.9962 - val_loss: 0.6434 - val_acc: 0.7222
# Test loss: 0.6433645268281301
# Test accuracy: 0.722222215599484

# %%
from sklearn.metrics import confusion_matrix,classification_report
import seaborn as sns
sns.set()
y_predict_test_prob=new_model.predict(x_test)
y_predict_test=np.argmax(y_predict_test_prob,axis=1)
y_real_test=np.argmax(y_test,axis=1)

# %%
y_predict_test_prob
# Out:
# array([[4.56382096e-01, 2.45986274e-03, 5.41158020e-01],
#        [8.44236195e-01, 1.02893874e-01, 5.28699644e-02],
#        [2.43391037e-01, 9.20545775e-03, 7.47403502e-01],
#        [4.61428463e-02, 7.10006198e-03, 9.46757138e-01],
#        [4.56482247e-02, 9.53204334e-01, 1.14749488e-03],
#        [9.13464129e-01, 1.50244124e-02, 7.15114251e-02],
#        [1.79652572e-02, 1.17480010e-02, 9.70286727e-01],
#        [8.47395837e-01, 2.75972998e-03, 1.49844408e-01],
#        [9.19276536e-01, 5.45499027e-02, 2.61736307e-02],
#        [7.80949712e-01, 1.23945205e-02, 2.06655771e-01],
#        [8.82780030e-02, 4.65790063e-01, 4.45931941e-01],
#        [9.58642736e-02, 8.69611323e-01, 3.45244445e-02],
#        [8.19644630e-01, 1.40556112e-01, 3.97992134e-02],
#        [8.85996997e-01, 2.66657248e-02, 8.73372853e-02],
#        [9.97252643e-01, 2.34425580e-03, 4.03142447e-04],
#        [6.49950579e-02, 2.34023808e-03, 9.32664692e-01],
#        [8.45501542e-01, 8.04758351e-03, 1.46450877e-01],
#        [8.72133553e-01, 2.81478208e-03, 1.25051662e-01],
#        [2.11641759e-01, 5.98628640e-01, 1.89729571e-01],
#        [2.53742516e-01, 1.27559202e-02, 7.33501494e-01],
#        [9.78725255e-01, 2.77977693e-03, 1.84950344e-02],
#        [9.74335551e-01, 2.42296839e-03, 2.32415125e-02],
#        [9.63804483e-01, 5.73181082e-03, 3.04636545e-02],
#        [6.66272759e-01, 2.72233076e-02, 3.06503922e-01],
#        [1.77427366e-01, 3.97146493e-02, 7.82857955e-01],
#        [9.93468165e-01, 3.41691170e-03, 3.11484910e-03],
#        [2.45193198e-01, 2.05424568e-03, 7.52752542e-01],
#        [9.99500871e-01, 2.73588725e-04, 2.25548778e-04],
#        [9.94348466e-01, 7.31415406e-04, 4.92023211e-03],
#        [9.99158859e-01, 3.89170047e-04, 4.52037493e-04],
#        [4.10743058e-01, 5.67230761e-01, 2.20261887e-02],
#        [1.36674210e-01, 8.59930217e-01, 3.39556532e-03],
#        [4.49333154e-03, 9.94744301e-01, 7.62369949e-04],
#        [3.45576275e-03, 9.96066868e-01, 4.77311987e-04],
#        [9.05726627e-02, 9.09151971e-01, 2.75346363e-04],
#        [1.96050182e-02, 9.07287300e-01, 7.31077269e-02],
#        [5.71831595e-03, 1.33892372e-01, 8.60389292e-01],
#        [7.30530322e-02, 7.90115893e-01, 1.36831135e-01],
#        [2.00251006e-02, 9.77567792e-01, 2.40717595e-03],
#        [7.25410521e-01, 2.47482911e-01, 2.71065775e-02],
#        [7.09310770e-01, 4.29160148e-02, 2.47773170e-01],
#        [1.27737492e-01, 8.37129056e-01, 3.51334587e-02],
#        [3.26757170e-02, 9.67227995e-01, 9.62386257e-05],
#        [1.15056507e-01, 4.65797246e-01, 4.19146240e-01],
#        [4.94414708e-04, 9.97236311e-01, 2.26924894e-03],
#        [2.68526971e-02, 2.79194042e-02, 9.45227861e-01],
#        [1.23648658e-01, 8.62748206e-01, 1.36031462e-02],
#        [3.21859628e-01, 4.07412469e-01, 2.70727873e-01],
#        [9.62951803e-04, 5.41413575e-02, 9.44895685e-01],
#        [3.59426998e-02, 3.79032731e-01, 5.85024536e-01],
#        [1.18386537e-01, 8.31335604e-01, 5.02777882e-02],
#        [8.04093294e-03, 5.30197263e-01, 4.61761862e-01],
#        [6.68845594e-01, 1.67663798e-01, 1.63490638e-01],
#        [3.94683540e-01, 6.02779627e-01, 2.53686984e-03],
#        [9.08266008e-02, 8.92582297e-01, 1.65910088e-02],
#        [4.02758643e-02, 9.39798772e-01, 1.99253876e-02],
#        [5.14982380e-02, 9.44523931e-01, 3.97776207e-03],
#        [5.56786358e-01, 2.85899788e-01, 1.57313779e-01],
#        [8.23096931e-01, 1.67366803e-01, 9.53626446e-03],
#        [1.39676295e-02, 9.64603722e-01, 2.14286875e-02],
#        [1.66192334e-02, 7.76237529e-03, 9.75618422e-01],
#        [1.65693217e-03, 8.83794054e-02, 9.09963608e-01],
#        [5.06313324e-01, 2.52094045e-02, 4.68477279e-01],
#        [4.21078242e-02, 2.61539499e-05, 9.57865953e-01],
#        [8.13126981e-01, 6.77051861e-03, 1.80102482e-01],
#        [2.91484326e-01, 8.01107090e-04, 7.07714558e-01],
#        [2.77187936e-02, 2.93084158e-04, 9.71988082e-01],
#        [2.50361338e-02, 2.33766681e-04, 9.74730074e-01],
#        [3.19269001e-01, 8.49903096e-03, 6.72231972e-01],
#        [2.79698265e-03, 5.39451428e-02, 9.43257868e-01],
#        [6.41370844e-03, 7.32903788e-03, 9.86257255e-01],
#        [2.05177329e-02, 3.06819420e-04, 9.79175448e-01],
#        [1.03850536e-04, 6.15942816e-04, 9.99280274e-01],
#        [4.67330450e-04, 1.92209875e-04, 9.99340475e-01],
#        [4.11448348e-03, 1.04565360e-03, 9.94839847e-01],
#        [7.51884771e-04, 7.96783192e-04, 9.98451352e-01],
#        [2.08486006e-01, 4.45605338e-01, 3.45908582e-01],
#        [3.87162477e-01, 5.90088684e-03, 6.06936634e-01],
#        [5.05521055e-03, 5.36668487e-02, 9.41277981e-01],
#        [8.09946377e-03, 2.98641669e-03, 9.88914073e-01],
#        [2.34114734e-04, 8.43026501e-04, 9.98922884e-01],
#        [6.74838126e-01, 3.60481464e-03, 3.21557015e-01],
#        [1.58558798e-03, 5.32929727e-04, 9.97881472e-01],
#        [3.67843779e-03, 4.71410167e-04, 9.95850086e-01],
#        [5.50492033e-02, 3.00688739e-03, 9.41943944e-01],
#        [5.48230310e-04, 5.27789583e-04, 9.98923957e-01],
#        [5.74423291e-04, 6.39642356e-03, 9.93029177e-01],
#        [3.24058998e-03, 2.24359334e-02, 9.74323511e-01],
#        [3.44729098e-03, 4.75589361e-04, 9.96077120e-01],
#        [2.03671074e-03, 2.13577412e-02, 9.76605535e-01]], dtype=float32)

# %%
mat_test = confusion_matrix(y_true=y_real_test, y_pred=y_predict_test,labels=[0,1,2])
sns.heatmap(mat_test, square = True, annot = True, cbar = False, cmap = 'RdPu')
plt.xlabel ('predicted fashion style')
plt.ylabel ('true fashion style')
# Out:
# Text(89.18,0.5,'true fashion style')

# %%
fig,axes=plt.subplots(9,10,
                      figsize=(20,20),
                      subplot_kw ={'xticks':[],'yticks':[]}, 
                      gridspec_kw = dict(hspace =0.1, wspace = 0.1)
                     )
for i, ax in enumerate(axes.flat):
    ax.imshow(x_test[i],cmap = 'binary', interpolation = 'nearest')
    ax.text(0.1, 0.3, str(y_real_test[i]),
        transform = ax.transAxes,
        color = 'green' if (y_predict_test[i] == y_real_test[i]) else 'red')
    
    ax.text(0.1, 0.1, str(y_predict_test[i]),
        transform = ax.transAxes,
        color = 'green' if (y_predict_test[i] == y_real_test[i]) else 'red')
plt.show()

# %%
fig,axes=plt.subplots(9,10,
                      figsize=(20,20),
                      subplot_kw ={'xticks':[],'yticks':[]}, 
                      gridspec_kw = dict(hspace =0.1, wspace = 0.1)
                     )
np.set_printoptions(precision=2)
for i,ax in enumerate(axes.flat):
    ax.imshow(x_test[i],cmap = 'binary', interpolation = 'nearest')
    ax.text(0.1, 0.4, str(y_real_test[i],),
        transform = ax.transAxes, #color = 'blue'
        color = 'green' if (y_predict_test[i] == y_real_test[i]) else 'red'
           )
    
    ax.text(0.1, 0.3, str(np.round(y_predict_test_prob[i,0],3),),
        transform = ax.transAxes,color = 'blue'
        #color = 'green' if (y_predict_test[i] == y_real_test[i]) else 'red'
           )
        
    ax.text(0.1, 0.2, str(np.round(y_predict_test_prob[i,1],3),),
        transform = ax.transAxes,color = 'blue'
        #color = 'green' if (y_predict_test[i] == y_real_test[i]) else 'red'
           )
    
    ax.text(0.1, 0.1, str(np.round(y_predict_test_prob[i,2],3),),
        transform = ax.transAxes,color = 'blue'
        #color = 'green' if (y_predict_test[i] == y_real_test[i]) else 'red'
           )

# %%
classification_report(y_true=y_real_test, y_pred=y_predict_test,labels=[0,1,2])
# Out:
# '             precision    recall  f1-score   support\n\n          0       0.69      0.60      0.64        30\n          1       0.81      0.70      0.75        30\n          2       0.68      0.87      0.76        30\n\navg / total       0.73      0.72      0.72        90\n'

# %%
y_predict_train_prob=new_model.predict(x_train)
y_predict_train=np.argmax(y_predict_train_prob,axis=1)
y_real_train=np.argmax(y_train,axis=1)

# %%
mat_train = confusion_matrix(y_true=y_real_train, y_pred=y_predict_train,labels=[0,1,2])
sns.heatmap(mat_train, square = True, annot = True, cbar = False, cmap = 'RdPu')
plt.xlabel ('predicted fashion style')
plt.ylabel ('true fashion style')
# Out:
# Text(89.18,0.5,'true fashion style')

# %%
classification_report(y_true=y_real_train, y_pred=y_predict_train,labels=[0,1,2])
# Out:
# '             precision    recall  f1-score   support\n\n          0       1.00      1.00      1.00       350\n          1       1.00      1.00      1.00       350\n          2       1.00      1.00      1.00       350\n\navg / total       1.00      1.00      1.00      1050\n'

# %%
#Accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
#loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
